# %%
import pandas as pd
import numpy as np


file_path = "data.csv"
data = pd.read_csv(file_path, encoding="latin1")
# Out:
# /tmp/ipython-input-2046610098.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, encoding="latin1")

# %%
print(data.columns)
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
x = data["no2"].dropna().values

# %%
r = 102303554

a = 0.05 * (r % 7)
b = 0.3 * ((r % 5) + 1)

print("a_r =", a)
print("b_r =", b)
# Out:
# a_r = 0.15000000000000002
# b_r = 1.5

# %%
z = x + a * np.sin(b * x)

# %%
mu = np.mean(z)
sigma2 = np.var(z)
lam = 1 / (2 * sigma2)
c = np.sqrt(lam / np.pi)

# %%
print("\nFINAL PARAMETERS TO SUBMIT:")
print("mu =", mu)
print("lambda =", lam)
print("c =", c)
# Out:
# FINAL PARAMETERS TO SUBMIT:
# mu = 25.814687284943872
# lambda = 0.0014612298133120176
# c = 0.021566731221112533
